# %% [markdown]
# <a href="https://colab.research.google.com/github/Madaranga/flipkart-regional-sales-analysis/blob/main/FlipKarttt_Regional_Sales_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Problem Statement**
#
# XYZ co's 2014-2018 sales data to identify key revenue and profit drivers across products, channels and regions, uncover saosonal trends and outliers to optimize pricing, promotions and market expansion for sustainable growth and reduced concentration risk.

# %%
from ast import increment_lineno
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sheets = pd.read_excel(
    '/content/drive/MyDrive/Colab Notebooks/Regional Sales Dataset.xlsx',
    sheet_name=None
)

# %%
# Assign dataframes to each sheet

df_sales = sheets['Sales Orders']
df_customers = sheets['Customers']
df_products = sheets['Products']
df_regions = sheets['Regions']
df_state_reg = sheets['State Regions']
df_budgets = sheets['2017 Budgets']

# %%
df_sales.head(5)
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost
# ...

# %%
print("df_sales shape: ",(df_sales.shape))
print("df_customers shape: ",(df_customers.shape))
print("df_products shape: ",(df_products.shape))
print("df_regions shape: ",(df_regions.shape))
print("df_state_reg shape: ",(df_state_reg.shape))
print("df_budgets shape: ",(df_budgets.shape))
# Out:
# df_sales shape:  (64104, 12)
# df_customers shape:  (175, 2)
# df_products shape:  (30, 2)
# df_regions shape:  (994, 15)
# df_state_reg shape:  (49, 3)
# df_budgets shape:  (30, 2)

# %%
df_sales.head(5)
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost
# ...

# %%
df_products.head(5)
# Out:
#    Index Product Name
# 0      1    Product 1
# 1      2    Product 2
# 2      3    Product 3
# 3      4    Product 4
# 4      5    Product 5

# %%
df_customers.head(5)
# Out:
#    Customer Index Customer Names
# 0               1  Geiss Company
# 1               2  Jaxbean Group
# 2               3     Ascend Ltd
# 3               4      Eire Corp
# 4               5   Blogtags Ltd

# %%
df_budgets.head(5)
# Out:
#   Product Name  2017 Budgets
# 0    Product 1   3016489.209
# 1    Product 2   3050087.565
# 2    Product 3   2642352.432
# 3    Product 4   2885560.824
# 4    Product 5   3925424.542

# %%
df_regions.head(5)
# Out:
#    id        name                                   county state_code  \
# 0   1      Auburn                               Lee County         AL
# 1   2  Birmingham           Shelby County/Jefferson County         AL
# 2   3     Decatur           Limestone County/Morgan County         AL
# 3   4      Dothan  Dale County/Houston County/Henry County         AL
# 4   5      Hoover           Shelby County/Jefferson County         AL
#
#      state  type  latitude  longitude  area_code  population  households  \
# 0  Alabama  City  32.60986  -85.48078        334       62059       21767
# 1  Alabama  City  33.52744  -86.79905        205      212461       89972
# 2  Alabama  City  34.57332  -86.99214        256       55437       22294
# 3  Alabama  City  31.23370  -85.40682        334       68567       25913
# 4  Alabama  City  33.37695  -86.80558        205       84848       32789
#
#    median_income  land_area  water_area        time_zone
# ...

# %%
df_state_reg.head(5)
# Out:
#       Column1     Column2 Column3
# 0  State Code       State  Region
# 1          AL     Alabama   South
# 2          AR    Arkansas   South
# 3          AZ     Arizona    West
# 4          CA  California    West

# %%
new_header = df_state_reg.iloc[0]
df_state_reg.columns = new_header
df_state_reg = df_state_reg[1:].reset_index(drop=True)

df_state_reg.head(5)
# Out:
# 0 State Code       State Region
# 0         AL     Alabama  South
# 1         AR    Arkansas  South
# 2         AZ     Arizona   West
# 3         CA  California   West
# 4         CO    Colorado   West

# %%
df_sales.isnull().sum()
# Out:
# OrderNumber                  0
# OrderDate                    0
# Customer Name Index          0
# Channel                      0
# Currency Code                0
# Warehouse Code               0
# Delivery Region Index        0
# Product Description Index    0
# Order Quantity               0
# Unit Price                   0
# Line Total                   0
# Total Unit Cost              0
# dtype: int64

# %%
 df_products.isnull().sum()
# Out:
# Index           0
# Product Name    0
# dtype: int64

# %%
df_regions.isnull().sum()
# Out:
# id               0
# name             0
# county           0
# state_code       0
# state            0
# type             0
# latitude         0
# longitude        0
# area_code        0
# population       0
# households       0
# median_income    0
# land_area        0
# water_area       0
# time_zone        0
# dtype: int64

# %%
df_customers.isnull().sum()
# Out:
# Customer Index    0
# Customer Names    0
# dtype: int64

# %%
df_budgets.isnull().sum()
# Out:
# Product Name    0
# 2017 Budgets    0
# dtype: int64

# %%
df_state_reg.isnull().sum()
# Out:
# 0
# State Code    0
# State         0
# Region        0
# dtype: int64

# %% [markdown]
# #### **Data Cleaning and Wrangling**

# %%
# merge with customers
df = df_sales.merge(
    df_customers,
    how='left',
    left_on='Customer Name Index',
    right_on='Customer Index'
)

# %%
df.head(5)
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost  Customer Index  \
# ...

# %%
# merge with products
df = df.merge(
    df_products,
    how='left',
    left_on='Product Description Index',
    right_on='Index'
)

# %%
df.head(5)
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  Line Total  Total Unit Cost  Customer Index  \
# ...

# %%
# merge with regions
df = df.merge(
    df_regions,
    how='left',
    left_on='Delivery Region Index',
    right_on='id'
)

# %%
df.head(5)
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  ...  type  latitude  longitude area_code  \
# ...

# %%
# merge with State Regions
df = df.merge(
    df_state_reg[["State Code","Region"]],
    how='left',
    left_on='state_code',
    right_on='State Code'
)

# %%
# merge with Budgets
df = df.merge(
    df_budgets,
    how='left',
    on='Product Name'
)

# %%
df.head(5)
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  ...  area_code  population  households  \
# ...

# %%
df.to_csv('file.csv')

# %%
#Customer Index
#Index
#id
#State Code

#Clean up redudant columns
cols_to_drop = ['Customer Index','Index', 'id', 'State Code']
df = df.drop(columns = cols_to_drop, errors='ignore')

df.head(5)
# Out:
#     OrderNumber  OrderDate  Customer Name Index      Channel Currency Code  \
# 0   SO - 000225 2014-01-01                  126    Wholesale           USD
# 1  SO - 0003378 2014-01-01                   96  Distributor           USD
# 2  SO - 0005126 2014-01-01                    8    Wholesale           USD
# 3  SO - 0005614 2014-01-01                   42       Export           USD
# 4  SO - 0005781 2014-01-01                   73    Wholesale           USD
#
#   Warehouse Code  Delivery Region Index  Product Description Index  \
# 0         AXW291                    364                         27
# 1         AXW291                    488                         20
# 2         AXW291                    155                         26
# 3         AXW291                    473                          7
# 4         AXW291                    256                          8
#
#    Order Quantity  Unit Price  ...  longitude  area_code population  \
# ...

# %%
#Convert all columns to lowe case for consistency and easier access
df.columns = df.columns.str.lower()

df.columns.values
# Out:
# array(['ordernumber', 'orderdate', 'customer name index', 'channel',
#        'currency code', 'warehouse code', 'delivery region index',
#        'product description index', 'order quantity', 'unit price',
#        'line total', 'total unit cost', 'customer names', 'product name',
#        'name', 'county', 'state_code', 'state', 'type', 'latitude',
#        'longitude', 'area_code', 'population', 'households',
#        'median_income', 'land_area', 'water_area', 'time_zone', 'region',
#        '2017 budgets'], dtype=object)

# %%
#KEEP THE IMPORTANT COLUMNS AND DELETE THE THAT WE DON'T NEED

cols_to_keep = [
    'ordernumber',
    'orderdate',
    'customer names',
    'channel',
    'order quantity',
    'unit price',
    'line total',
    'product name',
    'total unit cost',
    'state_code',
    'county',
    'region',
    'state',
    'latitude',
    'longitude',
    '2017 budgets'
]

# %%
df = df[cols_to_keep]

# %%
df.head(5)
# Out:
#     ordernumber  orderdate    customer names      channel  order quantity  \
# 0   SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale               6
# 1  SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor              11
# 2  SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale               6
# 3  SO - 0005614 2014-01-01  Colgate-Pa Group       Export               7
# 4  SO - 0005781 2014-01-01     Deseret Group    Wholesale               8
#
#    unit price  line total product name  total unit cost state_code  \
# 0      2499.1     14994.6   Product 27         1824.343         GA
# 1      2351.7     25868.7   Product 20         1269.918         IN
# 2       978.2      5869.2   Product 26          684.740         CA
# 3      2338.3     16368.1    Product 7         1028.852         IN
# 4      2291.4     18331.2    Product 8         1260.270         CT
#
#             county     region        state  latitude  longitude  2017 budgets
# ...

# %%
#rename columns

df = df.rename(columns={
    'ordernumber': 'order_number',
    'orderdate': 'order_date',
    'customer names': 'customer_name',
    'product name': 'product_name',
    'order quantity': 'order_quantity',
    'unit price': 'unit_price',
    'line total': 'revenue',
    'total unit cost': 'cost',
    'state_code': 'state',
    'state': 'state_name',
    'latitude': 'lat',
    'longitude': 'lon',
    '2017 budgets': 'budget'
})

df.head(5)
# Out:
#    order_number order_date     customer_name      channel  order_quantity  \
# 0   SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale               6
# 1  SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor              11
# 2  SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale               6
# 3  SO - 0005614 2014-01-01  Colgate-Pa Group       Export               7
# 4  SO - 0005781 2014-01-01     Deseret Group    Wholesale               8
#
#    unit_price  revenue product_name      cost state           county  \
# 0      2499.1  14994.6   Product 27  1824.343    GA   Chatham County
# 1      2351.7  25868.7   Product 20  1269.918    IN   Johnson County
# 2       978.2   5869.2   Product 26   684.740    CA   Alameda County
# 3      2338.3  16368.1    Product 7  1028.852    IN    Monroe County
# 4      2291.4  18331.2    Product 8  1260.270    CT  Hartford County
#
#       region   state_name       lat        lon       budget
# ...

# %%
df.loc[df['order_date'].dt.year != 2017, 'budget'] =pd.NA

#line_total is revenue
df[['order_date', 'product_name','revenue','budget']].head(5)
# Out:
#   order_date product_name  revenue  budget
# 0 2014-01-01   Product 27  14994.6     NaN
# 1 2014-01-01   Product 20  25868.7     NaN
# 2 2014-01-01   Product 26   5869.2     NaN
# 3 2014-01-01    Product 7  16368.1     NaN
# 4 2014-01-01    Product 8  18331.2     NaN

# %%
#line_total is revenue
df.to_csv('final.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64104 entries, 0 to 64103
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_number    64104 non-null  object
#  1   order_date      64104 non-null  datetime64[ns]
#  2   customer_name   64104 non-null  object
#  3   channel         64104 non-null  object
#  4   order_quantity  64104 non-null  int64
#  5   unit_price      64104 non-null  float64
#  6   revenue         64104 non-null  float64
#  7   product_name    64104 non-null  object
#  8   cost            64104 non-null  float64
#  9   state           64104 non-null  object
#  10  county          64104 non-null  object
#  11  region          64104 non-null  object
#  12  state_name      64104 non-null  object
#  13  lat             64104 non-null  float64
#  14  lon             64104 non-null  float64
#  15  budget          15263 non-null  float64
# ...

# %%
## Filter the dataset to include only records from year 2017
df_2017 = df[df['order_date'].dt.year == 2017]

df_2017.head(5)
# Out:
#        order_number order_date   customer_name    channel  order_quantity  \
# 46363  SO - 0002544 2017-01-01       NCS Group  Wholesale               6
# 46364  SO - 0006431 2017-01-01      Epic Group  Wholesale               5
# 46365  SO - 0007491 2017-01-01       State Ltd  Wholesale               9
# 46366  SO - 0008741 2017-01-01  Fivebridge Ltd  Wholesale               8
# 46367  SO - 0009295 2017-01-01     Tagfeed Ltd  Wholesale              12
#
#        unit_price  revenue product_name      cost state              county  \
# 46363      1239.5   7437.0   Product 30  1028.785    NJ       Hudson County
# 46364      1829.1   9145.5   Product 13  1207.206    CO         Mesa County
# 46365      2412.0  21708.0   Product 15  1664.280    CA  Los Angeles County
# 46366       904.5   7236.0    Product 8   750.735    IA      Dubuque County
# 46367      1112.2  13346.4    Product 2   811.906    FL     Hernando County
#
#           region  state_name       lat        lon       budget
# ...

# %%
df.isnull().sum()
# Out:
# order_number          0
# order_date            0
# customer_name         0
# channel               0
# order_quantity        0
# unit_price            0
# revenue               0
# product_name          0
# cost                  0
# state                 0
# county                0
# region                0
# state_name            0
# lat                   0
# lon                   0
# budget            48841
# dtype: int64

# %% [markdown]
# #### Feature Engineering

# %%
df.head(5)
# Out:
#    order_number order_date     customer_name      channel  order_quantity  \
# 0   SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale               6
# 1  SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor              11
# 2  SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale               6
# 3  SO - 0005614 2014-01-01  Colgate-Pa Group       Export               7
# 4  SO - 0005781 2014-01-01     Deseret Group    Wholesale               8
#
#    unit_price  revenue product_name      cost state           county  \
# 0      2499.1  14994.6   Product 27  1824.343    GA   Chatham County
# 1      2351.7  25868.7   Product 20  1269.918    IN   Johnson County
# 2       978.2   5869.2   Product 26   684.740    CA   Alameda County
# 3      2338.3  16368.1    Product 7  1028.852    IN    Monroe County
# 4      2291.4  18331.2    Product 8  1260.270    CT  Hartford County
#
#       region   state_name       lat        lon  budget
# ...

# %%
df['total_cost'] = df['order_quantity'] * df['cost']

# %%
df['profit'] = df['revenue'] - df['total_cost']
df['profit_margin_pct'] = df['profit'] / df['revenue']*100

# %%
df.head(5)
# Out:
#    order_number order_date     customer_name      channel  order_quantity  \
# 0   SO - 000225 2014-01-01     Rhynoodle Ltd    Wholesale               6
# 1  SO - 0003378 2014-01-01    Thoughtmix Ltd  Distributor              11
# 2  SO - 0005126 2014-01-01   Amerisourc Corp    Wholesale               6
# 3  SO - 0005614 2014-01-01  Colgate-Pa Group       Export               7
# 4  SO - 0005781 2014-01-01     Deseret Group    Wholesale               8
#
#    unit_price  revenue product_name      cost state           county  \
# 0      2499.1  14994.6   Product 27  1824.343    GA   Chatham County
# 1      2351.7  25868.7   Product 20  1269.918    IN   Johnson County
# 2       978.2   5869.2   Product 26   684.740    CA   Alameda County
# 3      2338.3  16368.1    Product 7  1028.852    IN    Monroe County
# 4      2291.4  18331.2    Product 8  1260.270    CT  Hartford County
#
#       region   state_name       lat        lon  budget  total_cost     profit  \
# ...
